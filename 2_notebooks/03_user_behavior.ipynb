# %%
import pandas as pd
from src.core.data_loader import load_clean_events

df = load_clean_events()
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
from src.analytics.user_behavior import user_behavior_analysis

result = user_behavior_analysis(df)

result
# Out:
# {'dau':            date    dau
#  0    2015-05-03   7865
#  1    2015-05-04  11019
#  2    2015-05-05  13084
#  3    2015-05-06  13687
#  4    2015-05-07  13086
#  ..          ...    ...
#  134  2015-09-14  13389
#  135  2015-09-15  12687
#  136  2015-09-16   6824
#  137  2015-09-17   6270
#  138  2015-09-18   1016
#
#  [139 rows x 2 columns],
#  'user_distribution': visitorid
#  1150086    7757
#  530559     4328
#  152963     3024
#  895999     2474
#  163561     2410
#             ...
#  285848        1
#  285849        1
#  25            1
#  26            1
#  27            1
#  Length: 1407580, dtype: int64,
#  'segments': low_active     1287208
#  mid_active      114323
#  high_active       6049
#  Name: count, dtype: int64,
#  'event_ratio': event
#  view           0.966823
#  addtocart      0.025027
#  transaction    0.008149
#  Name: proportion, dtype: float64,
#  'top_users': visitorid
#  1150086    7757
#  530559     4328
#  152963     3024
#  895999     2474
#  163561     2410
#  371606     2345
#  286616     2252
#  684514     2246
#  892013     2024
#  861299     1991
#  Name: count, dtype: int64}
